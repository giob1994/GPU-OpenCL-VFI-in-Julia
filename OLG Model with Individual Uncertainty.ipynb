# %% [markdown]
# # OLG Model with Individual Uncertainty

# %%
using Plots; gr()
using Rmath

# Setting up model parameters:

_eta       = 1.5
_beta      = 1.011
_alpha     = 0.36
_delta     = 0.06
_zeta      = 0.3
_gamma     = 2.0
_psi       = 0.001

_hbar      = 0.3

T          = 40  # maximum is 40
Tr         = 20  # maximum is 35

_rho       = 0.96
_sigma     = 0.045
_sigmay1   = 0.38

;

# %%
# Load survival probabilities [United Nations, 2002] and 
# age-productivity profile [Hansen, 1993] (normalised):

_Sprob = [ 1-(0.04)*(j/(T+Tr+20))^9 for j in 20:T+Tr+20 ]

plot(20:T+Tr+20, _Sprob, legend=false, title="Approximate Survival Probabilities")

# %%
Eff(x) = (-0.0006485)*x^2 + (0.06161)*x + (-0.3371)

_ybar  = [ Eff(j) for j in 20:T+20 ]

plot(20:T+20, _ybar, legend=false, title="Approximate Productivity Profile")

# %% [markdown]
# ## Preliminaries

# %%
# Initial mass distribution:
mass = ones(T+Tr)
for i in 2:length(mass)
    mass[i] = mass[i-1]*_Sprob[i-1]
end

# %%
# Mean effective labor supply :
_ybar = _ybar/mean(_ybar)
;

# %%
# Initialize the dicrete stochastic process:
Ny = 9

function tauchen(z_l, n, rho, sigma)
    #z = linspace(z_l, z_u, n)
    z = zeros(n)
    z[1] = z_l
    step = -2*z_l/(n-1)
    z[2:end] = [z_l + j*step for j in 2:n]
    #step = (z_u-z_l)/n
    P = zeros(n, n)
    for i in 1:n
        P[i,1] = pnorm((z[1]-rho*z[i])/sigma+step/(2*sigma))
        for j in 2:n-1
            P[i,j] = pnorm((z[j]-rho*z[i])/sigma+step/(2*sigma))-pnorm((z[j]-rho*z[i])/sigma-step/(2*sigma))
        end
        P[i,n] = 1-sum(P[i,:])
    end
    return collect(z), P.*(P .> 10.0^-6)
end

sy = _sigmay1
P = tauchen(-2*sy, Ny, _rho, _sigma)[2]

Ygrid = linspace(-2*sqrt(_sigma/(1-_rho^2)), 4*sqrt(_sigma/(1-_rho^2)), Ny)
;

# %%
# Initial distribution over productivity:
muy = zeros(T, Ny)
w = Ygrid[2]-Ygrid[1]
muy[1,1] = pnorm((Ygrid[1]+w/2)/sqrt(_sigmay1))
muy[1,Ny] = 1-pnorm((Ygrid[end]-w/2)/sqrt(_sigmay1))
muy[1,2:end-1] = [pnorm((Ygrid[j]+w/2)/sqrt(_sigmay1))-pnorm((Ygrid[j]-w/2)/sqrt(_sigmay1)) for j in 2:Ny-1]
for i in 2:T
    muy[i,:] = muy[i-1,:]'*P.*_Sprob[i]
end

plot(1:T, 1:Ny, muy', linetype=:surface, title="Productivity Distribution")

# %% [markdown]
# ## Standard Solution

# %%
# Prepare options for solution:

K_min = 0.0
K_max = 50.0
Nk    = 200
Kgrid = linspace(K_min, K_max, Nk)

# Finer grid for forward pass:
Nk_fine    = 2*Nk
Kgrid_fine = linspace(K_min, K_max, Nk_fine)

### INITIAL GUESSES ###

# Computing 'nbar':
nbar = 0.386

# Initial guess for the interest rate 'r':
r = 0.045

# Initial guess for the income tax 'tau':
tau = 0.2

# Compute 'kbar':
kbar = (_alpha/(r+_delta))^(1/(1-_alpha))*nbar

# Initialize 'w' and 'b':
w = 1 
b = 1

# Project 'x' on capital grid 'Kgrid':
gridind(x) = (K_min + x/(K_max-K_min)*(Nk-1)) + 1
togrid(x)  = Int(round(gridind(x)))

gridind_fine(x) = (K_min + x/(K_max-K_min)*(Nk_fine-1)) + 1

# Utility:
u(c) = (c^(1-_eta)-1)/(1-_eta)

function interpValueF_r(k, ValueFs)
    k0 = gridind(k)
    n1, n2 = k0-floor(k0), Int(floor(k0))
    if k <= K_min
        return ValueFs[1]-(1-k0)*(ValueFs[2]-ValueFs[1])
    elseif k >= K_max
        return ValueFs[end]
    else
        return (1-n1)*ValueFs[n2]+(n1)*ValueFs[n2+1]
    end
end

function interpValueF_w(k, j, ValueFs)
    # Note that this function only works if 'ValueFs_w'
    # is a 2D Array.
    k0 = gridind(k)
    n1, n2 = k0-floor(k0), Int(floor(k0))
    if k <= K_min
        return dot(P[j,:], ValueFs[1,:]-(1-k0)*(ValueFs[2,:]-ValueFs[1,:]))
    elseif k >= K_max
        return dot(P[j,:], ValueFs[end,:])
    else
        return dot(P[j,:], (1-n1)*ValueFs[n2,:]+(n1)*ValueFs[n2+1,:])
    end
end

function Value_r(k, x, ValueFs)
    c = (1+r)*k+b-x
    if c <= 0
        return u(10.0^-6)
    else
        return u(c)+_beta*interpValueF_r(x, ValueFs)
    end
end

function Value_w(k, x, t, j, ef, ValueFs)
    c = (1+r)*k+(1-tau)*w*ef*exp(Ygrid[j])*_hbar-x
    if c <= 0
        return u(10.0^-6)
    elseif t == T
        return u(c)+_beta*interpValueF_r(x, ValueFs)
    else 
        return u(c)+_beta*interpValueF_w(x, j, ValueFs)
    end
end

# Initialise value functions & policies:
ValueF_r = zeros(Nk, Tr)
Policy_r = ones(Int, Nk, Tr)
Consum_r = zeros(Nk, Tr)
ValueF_w = zeros(Nk, Ny, T)
Policy_w = ones(Int, Nk, Ny, Tr)
Consum_w = zeros(Nk, Ny, T)

# Initialise finer policies for forward pass:
Policy_w_fine = ones(Int, Nk*2, Ny, T)
Policy_r_fine = ones(Int, Nk*2, Ny, Tr)

# Forward distributions:
Dist_k_w = zeros(Nk_fine, Ny, T)
Dist_k_r = zeros(Nk_fine, Tr)
K_gen    = zeros(T+Tr)

;

# %%
print("---      Initial Values      ---")
print("--- Discretized Prd. Process ---")
println("---     Solution Settings    ---")
print(" nbar[init] = $(round(10^4*nbar)/10^4)\t\t|")
print(" Y_min      = $(round(10^4*Ygrid[1])/10^4)\t\t|")
println(" K_min      = $K_min")
print(" kbar[init] = $(round(10^4*kbar)/10^4)\t\t|")
print(" Y_max      = $(round(10^4*Ygrid[end])/10^4)\t\t|")
println(" K_max      = $K_max")
print(" r[init]    = $r\t\t|")
print(" N[Ygrid]   = $Ny\t\t|")
println(" N[Kgrid]   = $Nk")
print("--- ---- -------------- ---- ---")
print("--- ---- -------------- ---- ---")
println("--- ---- -------------- ---- ---\n")
println("--- [  Running  ] ---")

### SOLUTION ###

# Maximum number of iterations:
forit = 15

# Update rate:
_pphi = 0.3

tic()

for it in 1:forit
    
    tic()

    # (2) Compute implied values for w, r, band tau:
    w   = (1-_alpha)*kbar^_alpha*nbar^(-_alpha)
    r   = _alpha*kbar^(_alpha-1)*nbar^(1-_alpha)-_delta
    b   = _zeta*(1-tau)*w*nbar*(sum(mass)/sum(mass[1:T]))
    tau = _zeta*(sum(mass[T+1:T+Tr])/sum(mass))/(w*nbar)
    
    # Initialise value functions & policies:
    ValueF_r = zeros(Nk, Tr)
    Policy_r = ones(Int, Nk, Tr)
    Consum_r = zeros(Nk, Tr)
    
    ValueF_w = zeros(Nk, Ny, T)
    Policy_w = ones(Int, Nk, Ny, T)
    Consum_w = zeros(Nk, Ny, T)
    
    Policy_w_fine = ones(Int, Nk_fine, Ny, T)
    Policy_r_fine = ones(Int, Nk_fine, Ny, Tr)
    
    # [ T+Tr ] - Last period of life:
    Consum_r = (1+r)*Kgrid+b
    ValueF_r[:,end] = u.(Consum_r)
    
    # [ T+Tr-1, ..., T+1 ] - Retirement period:
    for s in Tr-1:-1:1 
        # For every 'k' on 'Kgrid':
        for k in 1:length(Kgrid)
            # Value function at the 'Kgrid' points:
            tmpVF(x) = Value_r(Kgrid[k], x, ValueF_r[:,s+1])
            #_VF = Value_r.(Kgrid[k], Kgrid, ValueF_r[:,s+1])
            _VF = tmpVF.(Kgrid)
            # Find the maximum on 'Kgrid'
            ValueF_r[k, s], Policy_r[k, s] = findmax(_VF)
        end
    end
    
    # [ T, ..., 1 ] - Working period:
    for s in T:-1:1
        # [ y[1], ..., y[Ny] ] - Productivity
        for j in 1:Ny
            # For every 'k' on 'Kgrid':
            for k in 1:length(Kgrid)
                # Transition from 'working' to 'retired':
                _VF = 0
                if s == T
                    _VF = map(x->Value_w(Kgrid[k], x, T, j, _ybar[T], ValueF_r[:,1]), Kgrid)
                # In 'working' period:
                else
                    # Value function at the 'Kgrid' points:
                    _VF = map(x->Value_w(Kgrid[k], x, s, j, _ybar[s], ValueF_w[:,:,s+1]), Kgrid)
                end
                # Find the maximum on 'Kgrid'
                ValueF_w[k, j, s], Policy_w[k, j, s] = findmax(_VF)
            end
        end
    end
    
    # Forward pass:
    
    # [ s = 1 ] - Every agent enters with 0 assets:
    Dist_k_w[1,:,1] = muy[1,:]
    K_gen[1] = dot(Kgrid_fine, squeeze(sum(Dist_k_w[:,:,1], 2),2))
    
    # [ 2, ..., T-1 ] - Working period:
    for s in 1:T-1
        for j in 1:Ny # Every 'y' on 'Ygrid'...
            for kf in 1:length(Kgrid_fine) # Every'k' on 'Kgrid'...
                k1 = 0
                if Kgrid_fine[kf] <= K_min
                    k1 = Kgrid[Policy_w[1,j,s]]
                elseif Kgrid_fine[kf] >= K_max
                    k1 = Kgrid[Policy_w[end,j,s]]
                else
                    n2 = Int(floor(gridind(Kgrid_fine[kf])))
                    n1 = (Kgrid_fine[kf]-Kgrid[n2])/(Kgrid[2]-Kgrid[1])
                    k1 = n1*Kgrid[Policy_w[n2,j,s]]+(1-n1)*Kgrid[Policy_w[n2+1,j,s]]
                end
                if k1 <= K_min
                    Dist_k_w[1, j, s+1] += dot(P[j,:], Dist_k_w[kf,:,s])
                elseif k1 >= K_max
                    Dist_k_w[end, j, s+1] += dot(P[j,:], Dist_k_w[kf,:,s])
                else
                    n3 = Int(floor(gridind_fine(k1)))
                    n1 = (k1-Kgrid_fine[n3])/(Kgrid_fine[2]-Kgrid_fine[1])
                    Dist_k_w[n3+1, j, s+1] += (n1).*dot(P[j,:], Dist_k_w[kf,:,s])
                    Dist_k_w[n3, j, s+1] += (1-n1).*dot(P[j,:], Dist_k_w[kf,:,s])
                end
            end
        end
        Dist_k_w[:, :, s+1] *= _Sprob[s+1]/sum(Dist_k_w[:, :, s+1])
        K_gen[s+1] = dot(Kgrid_fine, squeeze(sum(Dist_k_w[:,:,s+1], 2),2))
    end

    # T - Transition period:
    for j in 1:Ny # Every 'y' on 'Ygrid'...
        for kf in 1:length(Kgrid_fine) # Every'k' on 'Kgrid'...
            k1 = 0
            if Kgrid_fine[kf] <= K_min
                k1 = Kgrid[Policy_w[1,j,T]]
            elseif Kgrid_fine[kf] >= K_max
                k1 = Kgrid[Policy_w[end,j,T]]
            else
                n2 = Int(floor(gridind(Kgrid_fine[kf])))
                n1 = (Kgrid_fine[kf]-Kgrid[n2])/(Kgrid[2]-Kgrid[1])
                k1 = n1*Kgrid[Policy_w[n2,j,T]]+(1-n1)*Kgrid[Policy_w[n2+1,j,T]]
            end
            if k1 <= K_min
                Dist_k_r[1, 1] += Dist_k_w[kf,j,T]
            elseif k1 >= K_max
                Dist_k_r[end, 1] += Dist_k_w[kf,j,T]
            else
                n3 = Int(floor(gridind_fine(k1)))
                n1 = (k1-Kgrid_fine[n3])/(Kgrid_fine[2]-Kgrid_fine[1])
                Dist_k_r[n3+1, 1] += (n1).*Dist_k_w[kf,j,T]
                Dist_k_r[n3, 1] += (1-n1).*Dist_k_w[kf,j,T]
            end
        end
    end
    Dist_k_r[:, 1] *= _Sprob[T+1]/sum(Dist_k_r[:, 1])
    K_gen[T+1] = dot(Kgrid_fine, Dist_k_r[:,1])

     # [ T+1, ..., T+Tr ] - Retirement period:
    for s in 1:Tr-1
        for kf in 1:length(Kgrid_fine) # Every'k' on 'Kgrid'...
            k1 = 0
            if Kgrid_fine[kf] <= K_min
                k1 = Kgrid[Policy_r[1,s]]
            elseif Kgrid_fine[kf] >= K_max
                k1 = Kgrid[Policy_r[end,s]]
            else
                n2 = Int(floor(gridind(Kgrid_fine[kf])))
                n1 = (Kgrid_fine[kf]-Kgrid[n2])/(Kgrid[2]-Kgrid[1])
                k1 = n1*Kgrid[Policy_r[n2,s]]+(1-n1)*Kgrid[Policy_r[n2+1,s]]
            end
            if k1 <= K_min
                Dist_k_r[1, s+1] += Dist_k_r[kf,s]
            elseif k1 >= K_max
                Dist_k_r[end, s+1] += Dist_k_r[kf,s]
            else
                n3 = Int(floor(gridind_fine(k1)))
                n1 = (k1-Kgrid_fine[n3])/(Kgrid_fine[2]-Kgrid_fine[1])
                Dist_k_r[n3+1, s+1] += (n1).*Dist_k_r[kf,s]
                Dist_k_r[n3, s+1] += (1-n1).*Dist_k_r[kf,s]
            end
        end
        Dist_k_r[:, s+1] *= _Sprob[T+s+1]/sum(Dist_k_r[:, s+1])
        K_gen[T+s+1] = dot(Kgrid_fine, Dist_k_r[:,s+1])
    end
    
    # Update 'kbar' and proceed to new iteration:
    kbar_new = sum(K_gen)/sum(mass)
    kbar     = (1-_pphi)*kbar+_pphi*kbar_new
    
    print(" < it = $(@sprintf("%-3i",it)) , ")
    print("kbar[updated] = $(round(1000*kbar)/1000), ")
    print("kbar[new] = $(round(1000*kbar_new)/1000) >      "); 
    toc()

end

println("--- [   Done    ] ---")
println("\n\nTotal execution time:  ")
toc()

;
# Out:
# ---      Initial Values      ------ Discretized Prd. Process ------     Solution Settings    ---
#  nbar[init] = 0.386		| Y_min      = -1.5152		| K_min      = 0.0
#  kbar[init] = 2.6467		| Y_max      = 3.0305		| K_max      = 50.0
#  r[init]    = 0.045		| N[Ygrid]   = 9		| N[Kgrid]   = 200
# --- ---- -------------- ---- ------ ---- -------------- ---- ------ ---- -------------- ---- ---
#
# --- [  Running  ] ---
#  < it = 1   , kbar[updated] = 3.462, kbar[new] = 5.364 >      elapsed time: 84.337165607 seconds
#  < it = 2   , kbar[updated] = 4.023, kbar[new] = 5.332 >      elapsed time: 92.734069306 seconds
#  < it = 3   , kbar[updated] = 4.402, kbar[new] = 5.286 >      elapsed time: 85.096218901 seconds
#  < it = 4   , kbar[updated] = 4.652, kbar[new] = 5.235 >      elapsed time: 84.886224539 seconds
#  < it = 5   , kbar[updated] = 4.812, kbar[new] = 5.185 >      elapsed time: 88.403012495 seconds
#  < it = 6   , kbar[updated] = 4.909, kbar[new] = 5.137 >      elapsed time: 91.686013737 seconds
#  < it = 7   , kbar[updated] = 4.965, kbar[new] = 5.094 >      elapsed time: 90.642980426 seconds
#  < it = 8   , kbar[updated] = 4.992, kbar[new] = 5.055 >      elapsed time: 83.810246674 seconds
#  < it = 9   , kbar[updated] = 5.0, kbar[new] = 5.02 >      elapsed time: 84.598006756 seconds
#  < it = 10  , kbar[updated] = 4.997, kbar[new] = 4.989 >      elapsed time: 81.574453946 seconds
#  < it = 11  , kbar[updated] = 4.986, kbar[new] = 4.962 >      elapsed time: 87.364785056 seconds
#  < it = 12  , kbar[updated] = 4.972, kbar[new] = 4.939 >      elapsed time: 79.399742834 seconds
#  < it = 13  , kbar[updated] = 4.957, kbar[new] = 4.92 >      elapsed time: 77.740229581 seconds
#  < it = 14  , kbar[updated] = 4.941, kbar[new] = 4.904 >      elapsed time: 74.476306663 seconds
#  < it = 15  , kbar[updated] = 4.926, kbar[new] = 4.89 >      elapsed time: 89.757713734 seconds
# --- [   Done    ] ---
#
#
# Total execution time:
# elapsed time: 1277.011162909 seconds

# %%
# Average Capital Holdings:
plot(1:T+Tr+1, vcat(K_gen./mass, 0), title="Average Capital Holdings")

# %%
start_s = 2
lit     = 1
Kvec_   = zeros(Tr-start_s+1, 8)

for l in linspace(K_min+0.2, K_max, 8)
    ppath = togrid(l)
    Kvec_[1, lit] = ppath
    for s in start_s:Tr
        ppath = Policy_r[ppath, s]
        Kvec_[s-start_s+1, lit] = ppath
    end
    lit += 1
end
plot(1:Tr-start_s+1, Kvec_, legend=false, title="Retirees Paths")

# %%
plot(Kgrid, max.(ValueF_r[:,1:3:end], -500), legend=false, title="Value Functions - Retirees")
yaxis!("Value Function")
xaxis!("Capital k(s+1)")

# %%
s = T

p = plot()
for j = 1:Ny
    plot!(p, Kgrid, Ygrid[j]*ones(Kgrid), max.(ValueF_w[:,j,s], -500), leg=false, cbar=false, w=1, grid=true, title="Value Functions - Workers")
end
p
yaxis!("Value Function")
xaxis!("Capital k(s+1)")

# %% [markdown]
# ## GPU Accelerated Solution

# %%
using CLArrays, GPUArrays

### INITIAL GUESSES ###

# Computing 'nbar':
nbar = 0.386 # sum(muy.*exp.(Ygrid').*_ybar)*_hbar/sum(mass[1:T])

# Initial guess for the interest rate 'r':
r = 0.045

# Initial guess for the income tax 'tau':
tau = 0.2

# Compute 'kbar':
kbar = (_alpha/(r+_delta))^(1/(1-_alpha))*nbar

# Initialize 'w' and 'b':
w = 1 
b = 1


# Initialise value functions & policies on the GPU:
ValueF_r_gpu = zeros(CLArray{Float32}, Nk, Tr)
Policy_r_gpu = ones(CLArray{UInt32}, Nk, Tr)
Consum_r = zeros(Nk, Tr)

ValueF_w_gpu = zeros(CLArray{Float32}, Nk, Ny, T)
Policy_w_gpu = ones(CLArray{UInt32}, Nk, Ny, T)
Consum_w = zeros(Nk, Ny, T)

# Move the necessary elements to the GPU:
Kgrid_gpu  = CLArray(Array{Float32}(Kgrid))
Ygrid_gpu  = CLArray(Array{Float32}(Ygrid))
KYgrid_gpu = zeros(CLArray{UInt32}, Nk, Ny)
P_gpu      = CLArray(Array{Float32}(P))
params_gpu = CLArray(Array{Float32}([T; Tr; Nk; Ny; _beta; _eta; _hbar]))
rates_gpu  = CLArray(Array{Float32}([w; r; b; tau;]))

# Initialise finer policies for forward pass:
Policy_w_fine = ones(Int, Nk*2, Ny, Tr)
Policy_r_fine = ones(Int, Nk*2, Ny, T)

# Forward distributions:
Dist_k_w = zeros(Nk_fine, Ny, T)
Dist_k_r = zeros(Nk_fine, Tr)
K_gen    = zeros(T+Tr)


# GPU VF interation algorithms:
function Value_r_gpu(s)
    gpu_call(Kgrid_gpu, (Kgrid_gpu, ValueF_r_gpu, Policy_r_gpu, P_gpu, params_gpu, rates_gpu, UInt32(s), UInt32(Nk))) do state, Kgrid_gpu, ValueF_r_gpu, Policy_r_gpu, P_gpu, params_gpu, rates_gpu, s, Nk   
        # Each kernel executes for a 1D index in 'Kgrid':
        idx = @linearidx Kgrid_gpu 
        # If 's' = Tr then the task is trivial...
        if s == UInt32(params_gpu[2])
            c = (1+rates_gpu[2])*Kgrid_gpu[idx] + rates_gpu[3]
            ValueF_r_gpu[idx, s] = (c^(1-params_gpu[6])-1)/(1-params_gpu[6])
            Policy_r_gpu[idx, s] = UInt32(1)
            #return
        # If 's' = Tr-1, ..., 1 execute the VFI...
        else 
            # For every 'k' choice on 'Kgrid' at time 's+1'...
            v_temp  = Float32(0)
            v_max   = Float32(-Inf)
            ind_max = UInt32(1)
            for j in 1:Nk
                # Compute consumption:
                c = (1+rates_gpu[2])*Kgrid_gpu[idx] + rates_gpu[3] - Kgrid_gpu[j]
                # 'c' > 0 then the local value of the VF is not '-Inf':
                if c > 0
                    v_temp = (c^(1-params_gpu[6])-1)/(1-params_gpu[6]) + params_gpu[5]*ValueF_r_gpu[j,s+1]
                    # Store maximum value and its index...
                    if v_temp > v_max
                        v_max = v_temp
                        ind_max = UInt32(j)
                    end
                end
            end
            # 'v_max' and 'ind_max' identify the VFI results and the policy:
            ValueF_r_gpu[idx, s] = v_max
            Policy_r_gpu[idx, s] = ind_max 
        end
        return
    end
end
    
function Value_w_gpu(s, ef)
    gpu_call(KYgrid_gpu, (KYgrid_gpu, Kgrid_gpu, Ygrid_gpu, ValueF_w_gpu, Policy_w_gpu, ValueF_r_gpu, P_gpu, params_gpu, rates_gpu, UInt32(s), Float32(ef), UInt32(Nk), UInt32(Ny))) do state, KYgrid_gpu, Kgrid_gpu, Ygrid_gpu, ValueF_w_gpu, Policy_w_gpu, ValueF_r_gpu, P_gpu, params_gpu, rates_gpu, s, ef, Nk, Ny 
        # Each kernel executes for a 2D index in 'Kgrid'x'Ygrid'
        idx2  = @cartesianidx KYgrid_gpu
        idx_k = idx2[1]
        idx_y = idx2[2]
        # For every 'k' choice on 'Kgrid' at time 's+1'...
        v_temp  = Float32(0)
        v_max   = Float32(-Inf)
        ind_max = UInt32(1)
        for j in 1:Nk
            c = (1+rates_gpu[2])*Kgrid_gpu[idx_k] + (1-rates_gpu[4])*rates_gpu[1]*exp(Ygrid_gpu[idx_y])*params_gpu[7] - Kgrid_gpu[j]
            ValueF_w_gpu[idx_k, idx_y, s] = Float32(ef)
            if c > 0
                if s == params_gpu[1]
                    v_temp = (c^(1-params_gpu[6])-1)/(1-params_gpu[6]) + params_gpu[5]*ValueF_r_gpu[j,1]  
                else
                    #v_temp = (c^(1-params_gpu[6])-1)/(1-params_gpu[6])
                    p_temp = Float32(0)
                    for l in 1:Ny
                        p_temp = p_temp + params_gpu[5]*P_gpu[idx_y,l]*ValueF_w_gpu[j,l,s+1]
                    end 
                    v_temp = (c^(1-params_gpu[6])-1)/(1-params_gpu[6]) + p_temp
                end
                # Store maximum value and its index...
                if v_temp > v_max
                    v_max = v_temp
                    ind_max = UInt32(j)
                end   
            end
        end 
        ValueF_w_gpu[idx_k, idx_y, s] = v_max
        Policy_w_gpu[idx_k, idx_y, s] = ind_max 
        return
    end
end

# Initializing the OpenCL device & context:
cl_device = CLArrays.devices()[1]
CLArrays.init(cl_device)

# Pre-execution of the kernel to check for correct compilation:
@time Value_w_gpu(T, _ybar[T])
@time Value_r_gpu(Tr)

;

# %%
print("---      Initial Values      ---")
print("--- Discretized Prd. Process ---")
println("---     Solution Settings    ---")
print(" nbar[init] = $(round(10^4*nbar)/10^4)\t\t|")
print(" Y_min      = $(round(10^4*Ygrid[1])/10^4)\t\t|")
println(" K_min      = $K_min")
print(" kbar[init] = $(round(10^4*kbar)/10^4)\t\t|")
print(" Y_max      = $(round(10^4*Ygrid[end])/10^4)\t\t|")
println(" K_max      = $K_max")
print(" r[init]    = $r\t\t|")
print(" N[Ygrid]   = $Ny\t\t|")
println(" N[Kgrid]   = $Nk")
print("--- ---- -------------- ---- ---")
print("--- ---- -------------- ---- ---")
println("--- ---- -------------- ---- ---")
println(" #### [ using $(cl_device) ] #### \n")
println("--- [  Running (GPU)  ] ---")

### SOLUTION ###

# Maximum number of iterations:
forit = 100
it    = 1

# Update rate:
_pphi = 0.3

# Inital covergence criterion:
crit = 1

tic()

# Iterating until convergence:
while it < forit && crit > 10.0^-5
    
    tic()

    # Compute implied values for w, r, band tau:
    w   = (1-_alpha)*kbar^_alpha*nbar^(-_alpha)
    b   = _zeta*(1-tau)*w*nbar*(sum(mass)/sum(mass[1:T]))
    if it > 1
        r   = _alpha*kbar^(_alpha-1)*nbar^(1-_alpha)-_delta
        tau = _zeta*(sum(mass[T+1:T+Tr])/sum(mass))/(w*nbar)
    end
        
    rates_gpu = CLArray(Array{Float32}([w; r; b; tau;]))
    
    # Initialise value functions & policies:
    ValueF_r_gpu = zeros(CLArray{Float32}, Nk, Tr)
    Policy_r_gpu = ones(CLArray{UInt32}, Nk, Tr)
    Consum_r = zeros(Nk, Tr)
    
    ValueF_w_gpu = zeros(CLArray{Float32}, Nk, Ny, T)
    Policy_w_gpu = ones(CLArray{UInt32}, Nk, Ny, T)
    Consum_w = zeros(Nk, Ny, T)
    
    Policy_r_fine = ones(Int, Nk_fine, Ny, Tr)
    Policy_w_fine = ones(Int, Nk_fine, Ny, T)
    
    # [ T+Tr, ..., T+1 ] - Retirement period:
    for s in Tr-1:-1:1 
        Value_r_gpu(s)
    end
    
    # [ T, ..., 1 ] - Working period:
    for s in T:-1:1
        Value_w_gpu(s, _ybar[s])
    end
                    
    Policy_r = Array{UInt32}(Policy_r_gpu)
    Policy_w = Array{UInt32}(Policy_w_gpu)
    
    # Forward pass:
    
    # [ s = 1 ] - Every agent enters with 0 assets:
    Dist_k_w[1,:,1] = muy[1,:]
    K_gen[1] = dot(Kgrid_fine, squeeze(sum(Dist_k_w[:,:,1], 2),2))

    #println("s = 1  ",sum(Dist_k_w[:,:,1]))
    
    # [ 2, ..., T-1 ] - Working period:
    for s in 1:T-1
        for j in 1:Ny # Every 'y' on 'Ygrid'...
            for kf in 1:length(Kgrid_fine) # Every'k' on 'Kgrid'...
                k1 = 0
                if Kgrid_fine[kf] <= K_min
                    k1 = Kgrid[Policy_w[1,j,s]]
                elseif Kgrid_fine[kf] >= K_max
                    k1 = Kgrid[Policy_w[end,j,s]]
                else
                    n2 = Int(floor(gridind(Kgrid_fine[kf])))
                    n1 = (Kgrid_fine[kf]-Kgrid[n2])/(Kgrid[2]-Kgrid[1])
                    k1 = n1*Kgrid[Policy_w[n2,j,s]]+(1-n1)*Kgrid[Policy_w[n2+1,j,s]]
                end
                if k1 <= K_min
                    Dist_k_w[1, j, s+1] += dot(P[j,:], Dist_k_w[kf,:,s])
                elseif k1 >= K_max
                    Dist_k_w[end, j, s+1] += dot(P[j,:], Dist_k_w[kf,:,s])
                else
                    n3 = Int(floor(gridind_fine(k1)))
                    n1 = (k1-Kgrid_fine[n3])/(Kgrid_fine[2]-Kgrid_fine[1])
                    Dist_k_w[n3+1, j, s+1] += (n1).*dot(P[j,:], Dist_k_w[kf,:,s])
                    Dist_k_w[n3, j, s+1] += (1-n1).*dot(P[j,:], Dist_k_w[kf,:,s])
                end
            end
        end
        Dist_k_w[:, :, s+1] *= _Sprob[s+1]/sum(Dist_k_w[:, :, s+1])
        #println("s = $(s+1)  ",sum(Dist_k_w[:,:,s+1]))
        K_gen[s+1] = dot(Kgrid_fine, squeeze(sum(Dist_k_w[:,:,s+1], 2),2))
    end

    # T - Transition period:
    for j in 1:Ny # Every 'y' on 'Ygrid'...
        for kf in 1:length(Kgrid_fine) # Every'k' on 'Kgrid'...
            k1 = 0
            if Kgrid_fine[kf] <= K_min
                k1 = Kgrid[Policy_w[1,j,T]]
            elseif Kgrid_fine[kf] >= K_max
                k1 = Kgrid[Policy_w[end,j,T]]
            else
                n2 = Int(floor(gridind(Kgrid_fine[kf])))
                n1 = (Kgrid_fine[kf]-Kgrid[n2])/(Kgrid[2]-Kgrid[1])
                k1 = n1*Kgrid[Policy_w[n2,j,T]]+(1-n1)*Kgrid[Policy_w[n2+1,j,T]]
            end
            if k1 <= K_min
                Dist_k_r[1, 1] += Dist_k_w[kf,j,T]
            elseif k1 >= K_max
                Dist_k_r[end, 1] += Dist_k_w[kf,j,T]
            else
                n3 = Int(floor(gridind_fine(k1)))
                n1 = (k1-Kgrid_fine[n3])/(Kgrid_fine[2]-Kgrid_fine[1])
                Dist_k_r[n3+1, 1] += (n1).*Dist_k_w[kf,j,T]
                Dist_k_r[n3, 1] += (1-n1).*Dist_k_w[kf,j,T]
            end
        end
    end
    Dist_k_r[:, 1] *= _Sprob[T+1]/sum(Dist_k_r[:, 1])
    K_gen[T+1] = dot(Kgrid_fine, Dist_k_r[:,1])

    #println("s = T  ",sum(Dist_k_r[:,1]))

     # [ T+1, ..., T+Tr ] - Retirement period:
    for s in 1:Tr-1
        for kf in 1:length(Kgrid_fine) # Every'k' on 'Kgrid'...
            k1 = 0
            if Kgrid_fine[kf] <= K_min
                k1 = Kgrid[Policy_r[1,s]]
            elseif Kgrid_fine[kf] >= K_max
                k1 = Kgrid[Policy_r[end,s]]
            else
                n2 = Int(floor(gridind(Kgrid_fine[kf])))
                n1 = (Kgrid_fine[kf]-Kgrid[n2])/(Kgrid[2]-Kgrid[1])
                k1 = n1*Kgrid[Policy_r[n2,s]]+(1-n1)*Kgrid[Policy_r[n2+1,s]]
            end
            if k1 <= K_min
                Dist_k_r[1, s+1] += Dist_k_r[kf,s]
            elseif k1 >= K_max
                Dist_k_r[end, s+1] += Dist_k_r[kf,s]
            else
                n3 = Int(floor(gridind_fine(k1)))
                n1 = (k1-Kgrid_fine[n3])/(Kgrid_fine[2]-Kgrid_fine[1])
                Dist_k_r[n3+1, s+1] += (n1).*Dist_k_r[kf,s]
                Dist_k_r[n3, s+1] += (1-n1).*Dist_k_r[kf,s]
            end
        end
        Dist_k_r[:, s+1] *= _Sprob[T+s+1]/sum(Dist_k_r[:, s+1])
        #println("s = $(s+1)  ",sum(Dist_k_r[:,s]))
        K_gen[T+s+1] = dot(Kgrid_fine, Dist_k_r[:,s+1])
    end
    
    # Update 'kbar' and proceed to new iteration:
    kbar_new = sum(K_gen)/sum(mass)
    kbar     = (1-_pphi)*kbar+_pphi*kbar_new
    
    crit = abs(kbar-kbar_new)
    it += 1
    
    print(" < it = $(@sprintf("%-3i",it)) , ")
    print("kbar[updated] = $(round(1000*kbar)/1000), ")
    print("kbar[new] = $(round(1000*kbar_new)/1000) >      "); 
    toc()

end

println("--- [   Done (GPU)   ] ---")
println("\n\nTotal execution time:  ")
toc()

;
# Out:
# ---      Initial Values      ------ Discretized Prd. Process ------     Solution Settings    ---
#  nbar[init] = 0.386		| Y_min      = -1.5152		| K_min      = 0.0
#  kbar[init] = 2.6467		| Y_max      = 3.0305		| K_max      = 50.0
#  r[init]    = 0.045		| N[Ygrid]   = 9		| N[Kgrid]   = 200
# --- ---- -------------- ---- ------ ---- -------------- ---- ------ ---- -------------- ---- ---
#  #### [ using OpenCL.Device(Intel(R) Iris(TM) Graphics 550 on Apple @0x0000000001024500) ] ####
#
# --- [  Running (GPU)  ] ---
#  < it = 2   , kbar[updated] = 3.64, kbar[new] = 5.959 >      elapsed time: 0.579572997 seconds
#  < it = 3   , kbar[updated] = 4.322, kbar[new] = 5.912 >      elapsed time: 0.524678885 seconds
#  < it = 4   , kbar[updated] = 4.78, kbar[new] = 5.848 >      elapsed time: 0.524867479 seconds
#  < it = 5   , kbar[updated] = 5.08, kbar[new] = 5.78 >      elapsed time: 0.540755068 seconds
#  < it = 6   , kbar[updated] = 5.269, kbar[new] = 5.712 >      elapsed time: 0.657419108 seconds
#  < it = 7   , kbar[updated] = 5.382, kbar[new] = 5.647 >      elapsed time: 0.520802224 seconds
#  < it = 8   , kbar[updated] = 5.443, kbar[new] = 5.586 >      elapsed time: 0.516181353 seconds
#  < it = 9   , kbar[updated] = 5.469, kbar[new] = 5.529 >      elapsed time: 0.521406987 seconds
#  < it = 10  , kbar[updated] = 5.472, kbar[new] = 5.478 >      elapsed time: 0.550743326 seconds
#  < it = 11  , kbar[updated] = 5.46, kbar[new] = 5.432 >      elapsed time: 0.552674038 seconds
#  < it = 12  , kbar[updated] = 5.439, kbar[new] = 5.391 >      elapsed time: 0.572509968 seconds
#  < it = 13  , kbar[updated] = 5.414, kbar[new] = 5.354 >      elapsed time: 0.532364329 seconds
#  < it = 14  , kbar[updated] = 5.386, kbar[new] = 5.321 >      elapsed time: 0.540650199 seconds
#  < it = 15  , kbar[updated] = 5.358, kbar[new] = 5.292 >      elapsed time: 0.546681282 seconds
#  < it = 16  , kbar[updated] = 5.33, kbar[new] = 5.267 >      elapsed time: 0.569072574 seconds
#  < it = 17  , kbar[updated] = 5.305, kbar[new] = 5.245 >      elapsed time: 0.636710394 seconds
#  < it = 18  , kbar[updated] = 5.281, kbar[new] = 5.225 >      elapsed time: 0.562455008 seconds
#  < it = 19  , kbar[updated] = 5.259, kbar[new] = 5.209 >      elapsed time: 0.543490761 seconds
#  < it = 20  , kbar[updated] = 5.24, kbar[new] = 5.195 >      elapsed time: 0.547107224 seconds
#  < it = 21  , kbar[updated] = 5.223, kbar[new] = 5.182 >      elapsed time: 0.694609405 seconds
#  < it = 22  , kbar[updated] = 5.207, kbar[new] = 5.172 >      elapsed time: 0.543111193 seconds
#  < it = 23  , kbar[updated] = 5.194, kbar[new] = 5.162 >      elapsed time: 0.569997324 seconds
#  < it = 24  , kbar[updated] = 5.182, kbar[new] = 5.154 >      elapsed time: 0.80712707 seconds
#  < it = 25  , kbar[updated] = 5.172, kbar[new] = 5.148 >      elapsed time: 0.566907407 seconds
#  < it = 26  , kbar[updated] = 5.163, kbar[new] = 5.142 >      elapsed time: 0.521159619 seconds
#  < it = 27  , kbar[updated] = 5.155, kbar[new] = 5.137 >      elapsed time: 0.519602369 seconds
#  < it = 28  , kbar[updated] = 5.148, kbar[new] = 5.133 >      elapsed time: 0.527012801 seconds
#  < it = 29  , kbar[updated] = 5.143, kbar[new] = 5.13 >      elapsed time: 0.517056212 seconds
#  < it = 30  , kbar[updated] = 5.138, kbar[new] = 5.127 >      elapsed time: 0.527222664 seconds
#  < it = 31  , kbar[updated] = 5.134, kbar[new] = 5.125 >      elapsed time: 0.522177171 seconds
#  < it = 32  , kbar[updated] = 5.131, kbar[new] = 5.123 >      elapsed time: 0.553887823 seconds
#  < it = 33  , kbar[updated] = 5.128, kbar[new] = 5.121 >      elapsed time: 0.551799066 seconds
#  < it = 34  , kbar[updated] = 5.125, kbar[new] = 5.12 >      elapsed time: 0.549275038 seconds
#  < it = 35  , kbar[updated] = 5.123, kbar[new] = 5.119 >      elapsed time: 0.543890357 seconds
#  < it = 36  , kbar[updated] = 5.122, kbar[new] = 5.118 >      elapsed time: 0.5470603 seconds
#  < it = 37  , kbar[updated] = 5.121, kbar[new] = 5.118 >      elapsed time: 0.540880114 seconds
#  < it = 38  , kbar[updated] = 5.12, kbar[new] = 5.117 >      elapsed time: 0.543049886 seconds
#  < it = 39  , kbar[updated] = 5.119, kbar[new] = 5.117 >      elapsed time: 0.577763623 seconds
#  < it = 40  , kbar[updated] = 5.119, kbar[new] = 5.117 >      elapsed time: 0.66032366 seconds
#  < it = 41  , kbar[updated] = 5.118, kbar[new] = 5.118 >      elapsed time: 0.570379819 seconds
#  < it = 42  , kbar[updated] = 5.118, kbar[new] = 5.118 >      elapsed time: 0.713673226 seconds
#  < it = 43  , kbar[updated] = 5.118, kbar[new] = 5.118 >      elapsed time: 0.566416156 seconds
# --- [   Done (GPU)   ] ---
#
#
# Total execution time:
# elapsed time: 24.080788283 seconds

# %%
# Average Capital Holdings:
plot(1:T+Tr+1, vcat(K_gen./mass, 0), title="Average Capital Holdings - GPU")

# %%
start_s = 2
lit     = 1
Kvec_   = zeros(Tr-start_s+1, 8)

for l in linspace(K_min+0.2, K_max, 8)
    ppath = togrid(l)
    Kvec_[1, lit] = ppath
    for s in start_s:Tr
        ppath = Policy_r[ppath, s]
        Kvec_[s-start_s+1, lit] = ppath
    end
    lit += 1
end
plot(1:Tr-start_s+1, Kvec_, legend=false, title="Retirees Paths - GPU")

# %%
plot(Kgrid, max.(Array{Float64}(ValueF_r_gpu)[:,1:3:end], -500), legend=false, title="Value Functions - Retirees - GPU")
yaxis!("Value Function")
xaxis!("Capital k(s+1)")

# %%
s = T

p = plot()
for j = 1:Ny
    plot!(p, Kgrid, Ygrid[j]*ones(Kgrid), max.(Array{Float64}(ValueF_w_gpu)[:,j,s], -500), leg=false, cbar=false, w=1, grid=true, title="Value Functions - Workers - GPU")
end
p
yaxis!("Value Function")
xaxis!("Capital k(s+1)")

# %% [markdown]
# ## Performance

# %%
cpu_time      = 1277.011162909
cpu_time_proj = 3575
gpu_time      = 24.080788283
bar([1,2,3], [gpu_time, cpu_time, cpu_time_proj], xticks=[1, 2, 3], bar_width=0.6, legend=false, title="Performance Comparison - GPU vs CPU", xticks=[])
annotate!([(1,400,text("GPU\n(converged)",13,:center)),
          (2,1600,text("CPU\n(15 iterations)",13,:center)),
          (3,3000,text("CPU\n(estimated)",13,:white,:center)),
          (1.3, 2600,text("Speed gain: ~150x",15,:left,:grey,:center))])
